# %%
# demo_nosql_dummy.py

from NoSQL_package import NoSql, pretty_print_nosql


def demo_nosql_dummy():
    # 1) Initialize dummy data
    print("=== 1) Initialize dummy data ===")
    ns = NoSql()  # uses DUMMY_COUNTRY_LANGUAGE_DATA by default
    print(f"Total docs: {len(ns.data)}")
    print("First 5 docs:")
    pretty_print_nosql(NoSql(ns.data[:5]))

    # 2) Filter: language == 'English'
    print("\n=== 2) Filter: language == 'English' ===")
    query = {"language": "English"}
    filtered = ns.find(query)
    print(f"Matched docs: {len(filtered.data)}")
    pretty_print_nosql(NoSql(filtered.data[:5]))  # show first 5

    # 3) groupby + aggregate: count countries per language
    print("\n=== 3) group_by + aggregate: count per language ===")
    agg_spec = {
        "*": ["count"]   # special '*' = count docs in each group
    }
    grouped = ns.aggregate("language", agg_spec)
    for row in grouped:
        print(row)

    # 4) project: keep only code + country
    print("\n=== 4) project: only code, country ===")
    projected = ns.project({"code": 1, "country": 1})
    pretty_print_nosql(NoSql(projected.data[:5]))  # first 5

    # 5) self join on 'code'
    print("\n=== 5) self join on 'code' ===")
    joined = ns.join(
        from_field = ns,         # self join
        local_field = "code",
        foreign_field = "code",
        as_field = "matches"
    )
    print(f"Joined docs: {len(joined.data)}")
    pretty_print_nosql(NoSql(joined.data[:5]))  # first 5


if __name__ == "__main__":
    demo_nosql_dummy()
# Out:
# === 1) Initialize dummy data ===
# Total docs: 97
# First 5 docs:
# Document 1:
# {
#     code: 'IQ',
#     country: 'Iraq',
#     language: 'Arabic'
# }
#
# Document 2:
# {
#     code: 'CY',
#     country: 'Cyprus',
#     language: 'Greek'
# }
#
# Document 3:
# {
#     code: 'RS',
#     country: 'Serbia',
#     language: 'Serbian'
# }
#
# Document 4:
# {
#     code: 'CL',
#     country: 'Chile',
#     language: 'Spanish'
# }
#
# Document 5:
# {
#     code: 'LV',
#     country: 'Latvia',
#     language: 'Latvian'
# }
#
#
# === 2) Filter: language == 'English' ===
# Matched docs: 14
# Document 1:
# {
#     code: 'IE',
#     country: 'Ireland',
#     language: 'English'
# }
#
# Document 2:
# {
#     code: 'NG',
#     country: 'Nigeria',
#     language: 'English'
# }
#
# Document 3:
# {
#     code: 'US',
#     country: 'United States',
#     language: 'English'
# }
#
# Document 4:
# {
#     code: 'GH',
#     country: 'Ghana',
#     language: 'English'
# }
#
# Document 5:
# {
#     code: 'AU',
#     country: 'Australia',
#     language: 'English'
# }
#
#
# === 3) group_by + aggregate: count per language ===
# {'language': 'Arabic', 'count': 9}
# {'language': 'Greek', 'count': 2}
# {'language': 'Serbian', 'count': 1}
# {'language': 'Spanish', 'count': 15}
# {'language': 'Latvian', 'count': 1}
# {'language': 'English', 'count': 14}
# {'language': 'Macedonian', 'count': 1}
# {'language': 'Filipino', 'count': 1}
# {'language': 'Turkish', 'count': 1}
# {'language': 'Finnish', 'count': 1}
# {'language': 'Czech', 'count': 1}
# {'language': 'Sesotho', 'count': 1}
# {'language': 'French', 'count': 4}
# {'language': 'Mandarin Chinese', 'count': 2}
# {'language': 'Russian', 'count': 1}
# {'language': 'Dutch', 'count': 2}
# {'language': 'Slovene', 'count': 1}
# {'language': 'Urdu', 'count': 1}
# {'language': 'Swahili', 'count': 1}
# {'language': 'Vietnamese', 'count': 1}
# {'language': 'Italian', 'count': 1}
# {'language': 'German', 'count': 3}
# {'language': 'Lithuanian', 'count': 1}
# {'language': 'Norwegian', 'count': 1}
# {'language': 'Portuguese', 'count': 2}
# {'language': 'Japanese', 'count': 1}
# {'language': 'Romanian', 'count': 2}
# {'language': 'Hungarian', 'count': 1}
# {'language': 'Albanian', 'count': 1}
# {'language': 'Bosnian', 'count': 1}
# {'language': 'Slovak', 'count': 1}
# {'language': 'Samoan', 'count': 1}
# {'language': 'Thai', 'count': 1}
# {'language': 'Danish', 'count': 1}
# {'language': 'Ukrainian', 'count': 1}
# {'language': 'Indonesian', 'count': 1}
# {'language': 'Hindi', 'count': 1}
# {'language': 'Persian', 'count': 1}
# {'language': 'Armenian', 'count': 1}
# {'language': 'Zulu', 'count': 1}
# {'language': 'Maltese', 'count': 1}
# {'language': 'Malay', 'count': 1}
# {'language': 'Estonian', 'count': 1}
# {'language': 'Croatian', 'count': 1}
# {'language': 'Swedish', 'count': 1}
# {'language': 'Cantonese', 'count': 1}
# {'language': 'Luxembourgish', 'count': 1}
# {'language': 'Catalan', 'count': 1}
# {'language': 'Hebrew', 'count': 1}
# {'language': 'Bulgarian', 'count': 1}
# {'language': 'Korean', 'count': 1}
# {'language': 'Polish', 'count': 1}
#
# === 4) project: only code, country ===
# Document 1:
# {
#     code: 'IQ',
#     country: 'Iraq'
# }
#
# Document 2:
# {
#     code: 'CY',
#     country: 'Cyprus'
# }
#
# Document 3:
# {
#     code: 'RS',
#     country: 'Serbia'
# }
#
# Document 4:
# {
#     code: 'CL',
#     country: 'Chile'
# }
#
# Document 5:
# {
#     code: 'LV',
#     country: 'Latvia'
# }
#
#
# === 5) self join on 'code' ===
# Joined docs: 97
# Document 1:
# {
#     code: 'IQ',
#     country: 'Iraq',
#     language: 'Arabic',
#     matches:
#     [
#         {
#             code: 'IQ',
#             country: 'Iraq',
#             language: 'Arabic'
#         }
#     ]
# }
#
# Document 2:
# {
#     code: 'CY',
#     country: 'Cyprus',
#     language: 'Greek',
#     matches:
#     [
#         {
#             code: 'CY',
#             country: 'Cyprus',
#             language: 'Greek'
#         }
#     ]
# }
#
# Document 3:
# {
#     code: 'RS',
#     country: 'Serbia',
#     language: 'Serbian',
#     matches:
#     [
#         {
#             code: 'RS',
#             country: 'Serbia',
#             language: 'Serbian'
#         }
#     ]
# }
#
# Document 4:
# {
#     code: 'CL',
#     country: 'Chile',
#     language: 'Spanish',
#     matches:
#     [
#         {
#             code: 'CL',
#             country: 'Chile',
#             language: 'Spanish'
#         }
#     ]
# }
#
# Document 5:
# {
#     code: 'LV',
#     country: 'Latvia',
#     language: 'Latvian',
#     matches:
#     [
#         {
#             code: 'LV',
#             country: 'Latvia',
#             language: 'Latvian'
#         }
#     ]
# }

# %%
from NoSQL_package import NoSql, pretty_print_nosql

def demo_nosql_dummy_chunks_direct():
    print("=== 1) Initialize dummy data with chunk_size = 50 ===")

    # Read dummy data as chunks (generator), then wrap as single NoSql
    # so .data is a list of NoSql chunks.
    dummy_chunks = list(NoSql.read_dummy(chunk_size = 50))
    dummy_chunks = NoSql(dummy_chunks)   # << this is now our working object

    print(f"Chunked NoSql: {dummy_chunks!r}")
    # (Optional: quick sanity check on internal chunks)
    # for i, ch in enumerate(dummy_chunks.data, 1):
    #     print(f"  Inner chunk {i}: {len(ch.data)} docs")

    # 2) FILTER: language == 'English'
    print("\n=== 2) Filter on chunked NoSql: language == 'English' ===")
    query = {"language": "English"}
    filtered = dummy_chunks.find(query)
    print(f"Matched docs: {len(filtered.data)}")
    pretty_print_nosql(NoSql(filtered.data[:5]))  # show first 5 docs

    # 3) GROUPBY + AGG: count per language
    print("\n=== 3) group_by + aggregate on chunked NoSql: count per language ===")
    agg_spec = {
        "*": ["count"],   # special '*' means "count docs in each group"
    }
    grouped_rows = dummy_chunks.aggregate("language", agg_spec)
    for row in grouped_rows:
        print(row)

    # 4) PROJECT: only code, country
    print("\n=== 4) project on chunked NoSql: only code, country ===")
    projected = dummy_chunks.project({"code": 1, "country": 1})
    pretty_print_nosql(NoSql(projected.data[:5]))  # first 5 docs

    # 5) SELF JOIN on 'code'
    print("\n=== 5) self join on 'code' (chunked NoSql) ===")
    joined = dummy_chunks.join(
        from_field = dummy_chunks,   # self-join
        local_field = "code",
        foreign_field = "code",
        as_field = "matches",
    )
    print(f"Joined docs: {len(joined.data)}")
    pretty_print_nosql(NoSql(joined.data[:5]))  # first 5 docs


if __name__ == "__main__":
    demo_nosql_dummy_chunks_direct()
# Out:
# === 1) Initialize dummy data with chunk_size = 50 ===
# Chunked NoSql: NoSql(n_docs=2)
#
# === 2) Filter on chunked NoSql: language == 'English' ===
# Matched docs: 14
# Document 1:
# {
#     code: 'IE',
#     country: 'Ireland',
#     language: 'English'
# }
#
# Document 2:
# {
#     code: 'NG',
#     country: 'Nigeria',
#     language: 'English'
# }
#
# Document 3:
# {
#     code: 'US',
#     country: 'United States',
#     language: 'English'
# }
#
# Document 4:
# {
#     code: 'GH',
#     country: 'Ghana',
#     language: 'English'
# }
#
# Document 5:
# {
#     code: 'AU',
#     country: 'Australia',
#     language: 'English'
# }
#
#
# === 3) group_by + aggregate on chunked NoSql: count per language ===
# {'language': 'Arabic', 'count': 9}
# {'language': 'Greek', 'count': 2}
# {'language': 'Serbian', 'count': 1}
# {'language': 'Spanish', 'count': 15}
# {'language': 'Latvian', 'count': 1}
# {'language': 'English', 'count': 14}
# {'language': 'Macedonian', 'count': 1}
# {'language': 'Filipino', 'count': 1}
# {'language': 'Turkish', 'count': 1}
# {'language': 'Finnish', 'count': 1}
# {'language': 'Czech', 'count': 1}
# {'language': 'Sesotho', 'count': 1}
# {'language': 'French', 'count': 4}
# {'language': 'Mandarin Chinese', 'count': 2}
# {'language': 'Russian', 'count': 1}
# {'language': 'Dutch', 'count': 2}
# {'language': 'Slovene', 'count': 1}
# {'language': 'Urdu', 'count': 1}
# {'language': 'Swahili', 'count': 1}
# {'language': 'Vietnamese', 'count': 1}
# {'language': 'Italian', 'count': 1}
# {'language': 'German', 'count': 3}
# {'language': 'Lithuanian', 'count': 1}
# {'language': 'Norwegian', 'count': 1}
# {'language': 'Portuguese', 'count': 2}
# {'language': 'Japanese', 'count': 1}
# {'language': 'Romanian', 'count': 2}
# {'language': 'Hungarian', 'count': 1}
# {'language': 'Albanian', 'count': 1}
# {'language': 'Bosnian', 'count': 1}
# {'language': 'Slovak', 'count': 1}
# {'language': 'Samoan', 'count': 1}
# {'language': 'Thai', 'count': 1}
# {'language': 'Danish', 'count': 1}
# {'language': 'Ukrainian', 'count': 1}
# {'language': 'Indonesian', 'count': 1}
# {'language': 'Hindi', 'count': 1}
# {'language': 'Persian', 'count': 1}
# {'language': 'Armenian', 'count': 1}
# {'language': 'Zulu', 'count': 1}
# {'language': 'Maltese', 'count': 1}
# {'language': 'Malay', 'count': 1}
# {'language': 'Estonian', 'count': 1}
# {'language': 'Croatian', 'count': 1}
# {'language': 'Swedish', 'count': 1}
# {'language': 'Cantonese', 'count': 1}
# {'language': 'Luxembourgish', 'count': 1}
# {'language': 'Catalan', 'count': 1}
# {'language': 'Hebrew', 'count': 1}
# {'language': 'Bulgarian', 'count': 1}
# {'language': 'Korean', 'count': 1}
# {'language': 'Polish', 'count': 1}
#
# === 4) project on chunked NoSql: only code, country ===
# Document 1:
# {
#     code: 'IQ',
#     country: 'Iraq'
# }
#
# Document 2:
# {
#     code: 'CY',
#     country: 'Cyprus'
# }
#
# Document 3:
# {
#     code: 'RS',
#     country: 'Serbia'
# }
#
# Document 4:
# {
#     code: 'CL',
#     country: 'Chile'
# }
#
# Document 5:
# {
#     code: 'LV',
#     country: 'Latvia'
# }
#
#
# === 5) self join on 'code' (chunked NoSql) ===
# Joined docs: 97
# Document 1:
# {
#     code: 'IQ',
#     country: 'Iraq',
#     language: 'Arabic',
#     matches:
#     [
#         {
#             code: 'IQ',
#             country: 'Iraq',
#             language: 'Arabic'
#         }
#     ]
# }
#
# Document 2:
# {
#     code: 'CY',
#     country: 'Cyprus',
#     language: 'Greek',
#     matches:
#     [
#         {
#             code: 'CY',
#             country: 'Cyprus',
#             language: 'Greek'
#         }
#     ]
# }
#
# Document 3:
# {
#     code: 'RS',
#     country: 'Serbia',
#     language: 'Serbian',
#     matches:
#     [
#         {
#             code: 'RS',
#             country: 'Serbia',
#             language: 'Serbian'
#         }
#     ]
# }
#
# Document 4:
# {
#     code: 'CL',
#     country: 'Chile',
#     language: 'Spanish',
#     matches:
#     [
#         {
#             code: 'CL',
#             country: 'Chile',
#             language: 'Spanish'
#         }
#     ]
# }
#
# Document 5:
# {
#     code: 'LV',
#     country: 'Latvia',
#     language: 'Latvian',
#     matches:
#     [
#         {
#             code: 'LV',
#             country: 'Latvia',
#             language: 'Latvian'
#         }
#     ]
# }

# %%
from NoSQL_package import NoSql, pretty_print_nosql

def demo_nosql_json_chunks_direct(json_path: str, chunk_size: int = 50):
    print(f"=== 1) Initialize JSON data from: {json_path} (chunk_size = {chunk_size}) ===")

    # Load JSON file using chunking
    try:
        # read_json with chunk_size is expected to return a generator of NoSql chunks
        loaded_chunks = list(NoSql.read_json(json_path, chunk_size=chunk_size))
    except Exception as e:
        print(f"ERROR reading JSON: {e}")
        return

    # Wrap chunks inside a single NoSql object so .data is a list of NoSql chunks
    ns_obj = NoSql(loaded_chunks)

    print(f"Chunked NoSql: {ns_obj!r}")

    # 2) FILTER: example query (customize fields to your schema)
    print("\n=== 2) Filter on chunked NoSql: language == 'English' ===")
    query = {"language": "English"}  # change field name if needed
    try:
        filtered = ns_obj.find(query)
        print(f"Matched docs: {len(filtered.data)}")
        pretty_print_nosql(NoSql(filtered.data[:5]))  # show first 5 docs
    except Exception as e:
        print(f"Error during filter/find: {e}")

    # 3) GROUPBY + AGG: example grouping (customize fields to your schema)
    print("\n=== 3) group_by + aggregate on chunked NoSql: count per language ===")
    agg_spec = {
        "*": ["count"],   # special '*' means "count docs in each group"
    }
    try:
        grouped_rows = ns_obj.aggregate("language", agg_spec)
        for row in grouped_rows:
            print(row)
    except Exception as e:
        print(f"Error during aggregate: {e}")

    # 4) PROJECT: example projection (customize fields to your schema)
    print("\n=== 4) project on chunked NoSql: only code, country ===")
    try:
        projected = ns_obj.project({"code": 1, "country": 1})
        pretty_print_nosql(NoSql(projected.data[:5]))  # first 5 docs
    except Exception as e:
        print(f"Error during project: {e}")

    # 5) SELF JOIN: example self-join by 'code' (customize to your schema)
    print("\n=== 5) self join on 'code' (chunked NoSql) ===")
    try:
        joined = ns_obj.join(
            from_field = ns_obj,   # self-join
            local_field = "code",
            foreign_field = "code",
            as_field = "matches",
        )
        print(f"Joined docs: {len(joined.data)}")
        pretty_print_nosql(NoSql(joined.data[:5]))  # first 5 docs
    except Exception as e:
        print(f"Error during join: {e}")


# ---- Run the demo on your JSON file ----
json_path = "salaries.json"  # <-- put your JSON filename here
demo_nosql_json_chunks_direct(json_path, chunk_size=50)
# Out:
# === 1) Initialize JSON data from: salaries.json (chunk_size = 50) ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 66
#      64 # ---- Run the demo on your JSON file ----
#      65 json_path = "salaries.json"  # <-- put your JSON filename here
# ---> 66 demo_nosql_json_chunks_direct(json_path, chunk_size=50)
#
# Cell In[3], line 9, in demo_nosql_json_chunks_direct(json_path, chunk_size)
#       6 # Load JSON file using chunking
#       7 try:
#       8     # read_json with chunk_size is expected to return a generator of NoSql chunks
# ----> 9     loaded_chunks = list(NoSql.read_json(json_path, chunk_size=chunk_size))
#      10 except Exception as e:
#      11     print(f"ERROR reading JSON: {e}")
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:144, in _read_json_chunks(cls, filepath, chunk_size)
#     142 with open(filepath, "r", encoding="utf-8") as f:
#     143     start = f.read(1024)
# --> 144     if not start:
#     145         raise ValueError("File is empty")
#     146     stripped = start.lstrip()
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:108, in _read_json_all(cls, filepath)
#     104             yield cls(data[i : i + chunk_size])
#     106     return _gen()
# --> 108 @classmethod
#     109 def _read_json_all(cls, filepath: str) -> "NoSql":
#     110     with open(filepath, "r", encoding="utf-8") as f:
#     111         text = f.read().strip()
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:217, in _parse_list(cls, s)
#     213     rest = s[i:]
#     214     return value, rest
#     216 @classmethod
# --> 217 def _parse_list(cls, s):
#     218     s = s.lstrip()
#     219     if not s or s[0] != '[':
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:275, in _parse_value(cls, s)
#     273 if s[0] != ',':
#     274     raise ValueError(f"Expected ',' or '}}' in object, got: {repr(s[:10])}")
# --> 275 s = s[1:]
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:253, in _parse_object(cls, s)
#     250 if s and s[0] == '}':
#     251     return obj, s[1:]
# --> 253 while True:
#     254     s = s.lstrip()
#     255     if not s:
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:273, in _parse_value(cls, s)
#     271 if s[0] == '}':
#     272     return obj, s[1:]
# --> 273 if s[0] != ',':
#     274     raise ValueError(f"Expected ',' or '}}' in object, got: {repr(s[:10])}")
#     275 s = s[1:]
#
# File ~/Desktop/USC/DSCI551/Project/551_fa25/packages/NoSQL_package.py:175, in _parse_string(s)
#     173     raise ValueError(f"Line {i}: Extra content after JSON object")
#     174 batch.append(obj)
# --> 175 if len(batch) == chunk_size:
#     176     yield NoSql(batch)
#     177     batch = []
#
# KeyboardInterrupt:
